# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
from collections import Counter

# %%
df=pd.read_excel('./1. flixpatrol_1.xlsx')

# %%
df.head(1)
# Out:
#    Num              TITLE TYPE        COUNTRY    RELEASE  GENRE  COMPANY  \
# 0    1  The Queens Gambit   TV  United States 2020-10-23  Drama  Netflix
#
#    VALUE
# 0  44867

# %%
df_net = df[['TITLE','VALUE']]

# %%
df_net.head
# Out:
# <bound method NDFrame.head of                      TITLE  VALUE
# 0        The Queens Gambit  44867
# 1                 365 Days  42149
# 2           Emily in Paris  27138
# 3                  Lucifer  25729
# 4     The Umbrella Academy  23480
# ...                    ...    ...
# 3564          Just Friends      1
# 3565   Crank: High Voltage      1
# 3566              Child 44      1
# 3567        Dracula Untold      1
# 3568               Riddick      1
#
# [3569 rows x 2 columns]>

# %%
df_net=df_net.set_index('VALUE')

# %%
df_net
# Out:
#                       TITLE
# VALUE
# 44867     The Queens Gambit
# 42149              365 Days
# 27138        Emily in Paris
# 25729               Lucifer
# 23480  The Umbrella Academy
# ...                     ...
# 1              Just Friends
# 1       Crank: High Voltage
# 1                  Child 44
# 1            Dracula Untold
# 1                   Riddick
#
# [3569 rows x 1 columns]

# %%
type(df_net)
# Out:
# pandas.core.frame.DataFrame

# %%
net_mask = df.B(df_net)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-6b32bd473bf1> in <module>
# ----> 1 net_mask = df.collect(df_net)
#
# /Users/anaconda3/envs/tsa/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'collect'

# %%
net_mask
# Out:
# {'TITLE': {44867: 'The Queens Gambit',
#   42149: '365 Days',
#   27138: 'Emily in Paris',
#   25729: 'Lucifer',
#   23480: 'The Umbrella Academy',
#   22669: 'Money Heist',
#   21012: 'Dark Desire',
#   20937: 'The Crown',
#   17782: 'Friends',
#   16427: 'Enola Holmes',
#   16264: 'Yo soy Betty la fea',
#   15910: 'The Christmas Chronicles: Part Two',
#   15762: 'Ratched',
#   14831: 'Holidate',
#   14828: 'Pablo Escobar, The Drug Lord',
#   14794: 'Dark',
#   14145: 'The Last Dance',
#   13918: 'The Old Guard',
#   13853: 'Snowpiercer',
#   13588: 'The Social Dilemma',
#   13132: '100 Dias Para Enamorarnos',
#   13006: 'The Haunting of Bly Manor',
#   12833: 'The SpongeBob Movie: Sponge on the Run',
#   12791: 'Cursed',
#   12763: 'The Kissing Booth 2',
#   12270: 'Cobra Kai',
#   12023: 'Extraction',
#   11751: 'Its Okay to Not Be Okay',
#   11013: 'Paw Patrol',
#   10746: 'Locked Up',
#   10678: 'Modern Family',
#   10571: 'Hubie Halloween',
#   10536: 'Warrior Nun',
#   10529: 'Star Trek: Discovery',
#   10405: 'Too Hot to Handle',
#   10277: 'Away',
#   10165: 'Barbaren',
#   10069: 'Virgin River',
#   9711: 'Unsolved Mysteries',
#   9371: 'Tiny Pretty Things',
#   9032: 'CoComelon',
#   8751: 'Over the Moon',
#   8520: 'A California Christmas',
#   8494: 'Start-Up',
#   8246: '13 Reasons Why',
#   8240: 'The Devil All the Time',
#   8162: 'Work It',
#   7688: 'Love, Guaranteed',
#   7667: 'American Murder: The Family Next Door',
#   7468: 'Feel the Beat',
#   7438: 'Rick and Morty',
#   7275: 'The Christmas Chronicles',
#   7220: 'Jurassic World: Camp Cretaceous',
#   7146: 'The Princess Switch: Switched Again',
#   7044: 'White Lines',
#   7037: 'The King: Eternal Monarch',
#   6980: 'The 100',
#   6972: 'The Grinch',
#   6918: '#Alive',
#   6768: 'Operation Christmas Drop',
#   6673: 'Her Mothers Killer',
#   6541: 'Dynasty',
#   6524: 'The Boss Baby: Back in Business',
#   6480: 'The Sleepover',
#   6424: 'Space Force',
#   6402: 'Riverdale',
#   6381: 'The Wrong Missy',
#   6331: 'Rebecca',
#   6306: 'Bronx',
#   6303: 'Tiger King: Murder, Mayhem and Madness',
#   6261: 'The Order',
#   6171: 'Good Girls',
#   6053: 'Ozark',
#   6052: 'The Midnight Sky',
#   5966: 'Record of Youth',
#   5918: 'Amar y Vivir',
#   5912: 'How the Grinch Stole Christmas',
#   5720: 'Pasión de gavilanes',
#   5703: 'The Babysitter: Killer Queen',
#   5637: 'Floor is Lava',
#   5568: 'Mosul',
#   5560: 'The Paramedic',
#   5534: 'The Platform',
#   5505: 'To the Lake',
#   5485: 'The Mess You Leave Behind',
#   5466: 'Never Have I Ever',
#   5407: 'The Kissing Booth',
#   5358: 'MILF',
#   5336: 'Skyscraper',
#   5328: 'Outer Banks',
#   5307: 'The Blacklist',
#   5241: 'Desperados',
#   5185: 'The Last Days of American Crime',
#   5160: 'The Beast',
#   5109: 'Jeffrey Epstein: Filthy Rich',
#   5083: 'The Seven Deadly Sins',
#   5010: 'Despicable Me 2',
#   4829: 'Eurovision Song Contest: The Story of Fire Saga',
#   4648: 'The Willoughbys',
#   4620: 'Dangerous Lies',
#   4578: 'Jingle Jangle: A Christmas Journey',
#   4515: 'Crash Landing on You',
#   4476: 'Bridgerton',
#   4459: 'Lost Bullet',
#   4356: 'Prison Break',
#   4285: 'Unorthodox',
#   4267: '6 Underground',
#   4233: 'Jurassic World: Fallen Kingdom',
#   4162: 'How to Get Away with Murder',
#   4121: 'David Attenborough: A Life on Our Planet',
#   4104: 'The Prom',
#   4093: 'Toy Boy',
#   4081: 'The Sinner',
#   4049: 'Resurrection: Ertugrul',
#   4040: 'Demon Slayer: Kimetsu no Yaiba',
#   3922: 'Enemigo íntimo',
#   3869: 'What Men Want',
#   3807: 'We Can Be Heroes',
#   3793: 'Down to Earth with Zac Efron',
#   3759: 'The Trial of the Chicago 7',
#   3746: 'Was It Love',
#   3709: 'Sweet Home',
#   3698: 'Hospital Playlist',
#   3646: 'Selena: The Series',
#   3643: 'Wonder',
#   3617: 'Elite',
#   3564: 'Worlds Most Wanted',
#   3513: 'Dead to Me',
#   3502: 'Fatal Affair',
#   3465: 'Secrets of the Saqqara Tomb',
#   3437: 'Queen of the South',
#   3424: 'An Easy Girl',
#   3377: 'Blood of Zeus',
#   3359: 'Ava',
#   3306: 'The Witcher',
#   3281: 'Love. Wedding. Repeat',
#   3270: 'Despicable Me',
#   3239: 'Santana',
#   3215: 'A Babysitters Guide to Monster Hunting',
#   3190: 'The Secret: Dare to Dream',
#   3185: 'The Half of It',
#   3165: 'La Révolution',
#   3158: 'Johnny English Strikes Again',
#   3144: 'Big Mouth',
#   2980: 'Money Heist: The Phenomenon',
#   2971: 'The Call',
#   2942: 'Fifty Shades Freed',
#   2889: 'Hoops',
#   2887: 'Aquaman',
#   2883: 'The Rain',
#   2878: 'Da 5 Bloods',
#   2856: 'Pets United',
#   2855: 'El Dragón: Return of a Warrior',
#   2850: 'Instant Family',
#   2846: 'How to Sell Drugs Online (Fast)',
#   2788: 'Harry Potter and the Philosophers Stone',
#   2785: 'Mystic Pop-Up Bar',
#   2760: 'Miracle in Cell No. 7',
#   2730: 'BLACKPINK: Light Up the Sky',
#   2720: 'Family Guy',
#   2713: 'The Last Kingdom',
#   2701: 'The Business of Drugs',
#   2691: 'Trinkets',
#   2665: 'Fear City: New York vs The Mafia',
#   2659: 'Grizzy & the Lemmings',
#   2655: 'Alien Worlds',
#   2649: 'If Anything Happens I Love You',
#   2640: 'Time Trap',
#   2638: 'Freud',
#   2627: 'Furious 7',
#   2580: 'Freaks – Youre One of Us',
#   2568: 'Code 8',
#   2567: 'Bimilui Soop',
#   2541: 'Baby',
#   2527: 'Greys Anatomy',
#   2517: 'Animal Crackers',
#   2502: 'Into the Night',
#   2487: 'A Million Ways to Die in the West',
#   2480: 'Dad Wanted',
#   2479: 'The World of the Married',
#   2468: 'The Equalizer 2',
#   2448: 'Justice League',
#   2395: 'Rose Island',
#   2383: 'The Meg',
#   2370: 'Deadly Class',
#   2365: 'Get Organized with The Home Edit',
#   2336: 'The Purge: Anarchy',
#   2335: 'Dirty John',
#   2320: 'The Great Heist',
#   2318: 'The Flash',
#   2316: 'Vikings',
#   2312: 'The Life Ahead',
#   2305: 'Midnight at the Magnolia',
#   2301: 'Just Another Christmas',
#   2293: 'Night School',
#   2290: 'Biohackers',
#   2268: 'Coffee & Kareem',
#   2251: 'Seriously Single',
#   2237: 'Suits',
#   2208: 'The F**k-It List',
#   2206: 'The Barrier',
#   2203: 'Home for Christmas',
#   2185: 'American Assassin',
#   2182: 'Murder Mystery',
#   2180: 'Focus',
#   2174: 'The Boss Baby: Get That Baby!',
#   2169: 'Hotel Transylvania 3: Summer Vacation',
#   2159: 'The Star',
#   2156: 'Mortal Engines',
#   2152: 'Spider-Man: Homecoming',
#   2138: 'The Ripper',
#   2113: 'Youve Got This',
#   2108: 'In the Heart of the Sea',
#   2097: 'Christmas Made to Order',
#   2079: 'Sweet Magnolias',
#   2073: 'Itaewon Class',
#   2062: 'Control Z',
#   2047: 'Brooklyn Nine-Nine',
#   2040: 'Ludo',
#   2019: 'Spider-Man: Into the Spider-Verse',
#   2008: 'Selling Sunset',
#   2006: 'Bumblebee',
#   2004: 'High Score',
#   1992: 'Paranormal',
#   1970: 'The End of Paradise',
#   1961: 'Spenser Confidential',
#   1930: 'History 101',
#   1897: 'The Alienist',
#   1889: 'Rampage',
#   1882: 'Mission: Impossible - Fallout',
#   1859: 'The Holiday',
#   1855: 'ariana grande: excuse me, i love you',
#   1850: 'The Princess Switch',
#   1847: 'Jane the Virgin',
#   1838: 'Dont Listen',
#   1808: 'Harry Potter and the Chamber of Secrets',
#   1795: 'The Walking Dead',
#   1793: 'The First Purge',
#   1784: 'Better Call Saul',
#   1781: 'Geostorm',
#   1778: 'Safe House',
#   1750: 'The Main Event',
#   1725: 'The Baby-Sitters Club',
#   1712: 'Bad Boys for Life',
#   1710: 'Double World',
#   1709: 'Parker',
#   1707: 'Kärlek & Anarki',
#   1705: 'Schitts Creek',
#   1704: 'Valeria',
#   1699: 'All Together Now',
#   1684: 'Jumanji: The Next Level',
#   1661: 'A Suitable Boy',
#   1659: 'Hollywood',
#   1645: 'A Star is Born',
#   1643: 'Undercover',
#   1612: 'Tammy',
#   1608: 'Anne with an E',
#   1607: 'The Gift',
#   1602: 'Hillbilly Elegy',
#   1598: 'Siberia',
#   1594: 'Behzat Ç.',
#   1592: 'Intuition',
#   1591: 'A Simple Favor',
#   1584: 'Earth and Blood',
#   1583: 'Chica Vampiro',
#   1574: 'Sex Education',
#   1563: 'Escape Plan',
#   1554: 'Teenage Bounty Hunters',
#   1533: 'Bloodshot',
#   1523: 'Pacific Rim: Uprising',
#   1519: 'Lucy',
#   1517: 'Baby Driver',
#   1507: 'Do Do Sol Sol La La Sol',
#   1500: 'The Good Place',
#   1489: 'Cadaver',
#   1477: 'Nobody Sleeps In The Woods Tonight',
#   1476: 'Cinderela Pop',
#   1471: 'Crazy Rich Asians',
#   1461: 'Despicable Me 3',
#   1460: 'Scooby-Doo 2: Monsters Unleashed',
#   1448: 'Ready Player One',
#   1425: 'Death to 2020',
#   1420: 'Norbit',
#   1413: 'The Big Show Show',
#   1408: 'Dare Me',
#   1395: 'Ted',
#   1392: 'It',
#   1389: 'Wasp Network',
#   1373: 'Wizards: Tales of Arcadia',
#   1368: 'All Day and a Night',
#   1360: 'Glow Up: Britains Next Make-Up Star',
#   1346: 'Indian Matchmaking',
#   1334: 'Oceans 8',
#   1332: 'Alexa & Katie',
#   1323: '12 Strong',
#   1315: 'The Fabulous Lives of Bollywood Wives',
#   1312: 'Bad Boy Billionaires: India',
#   1305: 'Cable Girls',
#   1300: 'The Letter for the King',
#   1298: 'How to Train Your Dragon: The Hidden World',
#   1293: 'Wonder Woman',
#   1271: 'The Fall',
#   1264: 'Reply 1988',
#   1243: 'Becoming',
#   1240: 'Princess Sarah',
#   1239: 'The Occupant',
#   1236: 'Sniper: Ultimate Kill',
#   1233: 'Ride Along',
#   1232: 'The Liberator',
#   1226: 'Torbaaz',
#   1223: 'Blockers',
#   1220: 'Inside the Worlds Toughest Prisons',
#   1219: 'Summertime',
#   1209: 'Ginny Weds Sunny',
#   1206: 'Ethos',
#   1205: 'King Arthur: Legend of the Sword',
#   1203: 'Offering to the Storm',
#   1202: 'Have a Good Trip: Adventures in Psychedelics',
#   1196: 'Johnny English Reborn',
#   1189: 'Gemini Man',
#   1186: 'Harry Potter and the Prisoner of Azkaban',
#   1184: 'Upgrade',
#   1182: 'Vacation',
#   1177: 'Savages',
#   1168: 'Fast Five',
#   1167: 'Im Thinking of Ending Things',
#   1163: 'The Crimes That Bind',
#   1159: 'Tom and Jerry: The Movie',
#   1148: 'The Nun',
#   1146: 'The Angry Birds Movie 2',
#   1143: 'Chiquititas',
#   1142: 'Alguien tiene que morir',
#   1137: 'The Silence of the Marsh',
#   1136: 'The Decline',
#   1127: 'The Lovebirds',
#   1121: 'Space Jam',
#   1119: 'American Sniper',
#   1118: 'Goblin',
#   1117: 'Fantastic Beasts: The Crimes of Grindelwald',
#   1115: 'Mercury Rising',
#   1112: 'The Losers',
#   1105: 'Neighbors',
#   1097: 'Mismatched',
#   1093: 'Peppa Pig',
#   1090: 'Marcella',
#   1088: 'The Worst Witch',
#   1082: 'Curon',
#   1079: 'Battleship',
#   1063: 'Blood Diamond',
#   1062: 'Dunkirk',
#   1059: 'Truth or Dare',
#   1046: 'What We Wanted',
#   1043: 'La Piloto',
#   1037: 'The Impossible',
#   1033: 'Wanted',
#   1031: 'The 2nd',
#   1027: 'Hi Bye, Mama!',
#   1020: 'Charlies Angels',
#   1015: 'The Lorax',
#   1013: 'Oloture',
#   1005: 'The Mask',
#   1001: 'Blade Runner 2049',
#   993: 'After We Collided',
#   992: 'Community',
#   983: 'Citation',
#   978: 'Julie and the Phantoms',
#   966: 'Stateless',
#   965: 'No Manches Frida',
#   957: 'Serious Men',
#   950: 'Jumanji: Welcome to the Jungle',
#   949: 'A Quiet Place',
#   948: 'Athlete A',
#   947: 'Parasite',
#   945: 'Fire Force',
#   936: 'His House',
#   935: 'From Prada to Nada',
#   934: 'Doomsday',
#   933: '(Un)Well',
#   932: 'Sniper: Legacy',
#   927: 'The Queen of Flow',
#   925: 'Gunjan Saxena: The Kargil Girl',
#   922: 'Howls Moving Castle',
#   917: 'Joker',
#   914: 'Grown Ups',
#   912: 'New Girl',
#   907: '18 Presents',
#   900: 'Room 2806: The Accusation',
#   889: 'Ultras',
#   888: 'Fantasy Island',
#   886: 'The Invention of Lying',
#   879: 'The Stand In',
#   876: 'Charlie and the Chocolate Factory',
#   865: 'The Change-Up',
#   860: 'Alpha',
#   858: 'The Intern',
#   853: 'The Wolf of Wall Street',
#   851: 'A Whisker Away',
#   850: 'Jack Reacher',
#   848: 'I Love You, Stupid',
#   845: 'Death Wish',
#   843: 'Get Hard',
#   842: '8 Mile',
#   841: 'Going in Style',
#   828: 'Hes Out There',
#   827: 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#   826: 'Father Figures',
#   825: 'Whats Wrong with Secretary Kim',
#   823: 'Love is Blind',
#   818: 'Shazam!',
#   816: 'Contagion',
#   814: 'The Legend of Korra',
#   805: 'Cuties',
#   803: 'Den of Thieves',
#   802: 'Sicario: Day Of The Soldado',
#   798: 'The SpongeBob SquarePants Movie',
#   797: 'Keeping Up with the Kardashians',
#   794: 'Self Made: Inspired by the Life of Madam C.J. Walker',
#   792: 'My Hero Academia',
#   791: 'Life of the Party',
#   790: 'Robin Hood',
#   787: 'Run All Night',
#   786: 'Jack Ryan: Shadow Recruit',
#   782: 'Coronavirus, Explained',
#   780: 'Slender Man',
#   779: 'Cloudy with a Chance of Meatballs 2',
#   777: 'Think Like a Dog',
#   776: 'The Big Bang Theory',
#   772: 'G.I. Joe: Retaliation',
#   769: 'Attack on Titan',
#   765: 'Assassins Creed',
#   764: 'Outlander',
#   762: 'Instructions Not Included',
#   760: 'The SpongeBob Movie: Sponge Out of Water',
#   759: 'Mamma Mia: Here We Go Again!',
#   754: 'The Foreigner',
#   749: 'The Legacy of the Bones',
#   748: 'Breaking In',
#   747: 'Faster',
#   744: 'Due Date',
#   741: 'Jujutsu Kaisen',
#   737: 'Little Italy',
#   731: 'It Chapter Two',
#   728: 'Harry Potter and the Half-Blood Prince',
#   726: 'The House of Flowers',
#   725: 'Carmel: Who Killed Maria Marta?',
#   723: 'The Ninth Gate',
#   721: 'H',
#   720: 'Sing',
#   708: 'John Wick: Chapter Two',
#   707: 'Sergio',
#   705: 'Latte and the Magic Waterstone',
#   703: '300: Rise of an Empire',
#   701: 'The School Nurse Files',
#   700: 'Challenger: The Final Flight',
#   697: 'Scooby-Doo',
#   693: 'O Vendedor de Sonhos',
#   692: 'Mohamed Hussein',
#   690: 'Contraband',
#   689: 'El Testamento de la Abuela',
#   688: 'Pride & Prejudice',
#   687: 'Overlord',
#   686: 'The Bureau of Magical Things',
#   682: 'Extracurricular',
#   681: 'Little Women',
#   680: 'The Last Witch Hunter',
#   670: 'Harry Potter and the Goblet of Fire',
#   665: 'Smallfoot',
#   662: 'Anna',
#   659: 'Green Lantern',
#   658: 'Cómo Matar a un Esposo Muerto',
#   657: 'Independence Day: Resurgence',
#   656: 'The Dark Knight',
#   651: 'Tears of the Sun',
#   645: 'The Hunger Games',
#   644: 'Couples Retreat',
#   641: 'RuPauls Drag Race All Stars',
#   639: 'The Suit',
#   634: 'Criminal: UK',
#   633: 'X-Men: Apocalypse',
#   632: 'Creed II',
#   631: 'Little',
#   630: 'Fearless',
#   629: 'Fuller House',
#   628: 'Mission: Impossible - Rogue Nation',
#   626: 'Chefs Table: BBQ',
#   624: 'Paava Kadhaigal',
#   623: 'Heart Signal',
#   620: 'Rust Valley Restorers',
#   619: 'Solomon Kane',
#   617: 'Unforgettable',
#   615: 'Mighty Express',
#   614: 'The Little Rascals',
#   612: 'Happy New Year',
#   611: 'The Thieves',
#   610: 'The Tuxedo',
#   609: 'Boys Over Flowers',
#   608: 'The Italian Job',
#   603: 'Haikyu!!',
#   597: 'Under the Riccione Sun',
#   596: 'World War Z',
#   595: 'Kidnap',
#   594: 'Emerson Heights',
#   589: 'Mad Max: Fury Road',
#   588: 'Pitch Perfect 3',
#   586: 'Downsizing',
#   585: 'Reality Z',
#   583: 'Time to Hunt',
#   579: 'Girls Trip',
#   578: 'The Fate of the Furious',
#   576: 'Murder to Mercy: The Cyntoia Brown Story',
#   575: 'Shooter',
#   573: 'Barbie: Princess Adventure',
#   572: 'Fist Fight',
#   571: 'Anelka: Misunderstood',
#   570: 'Unbroken',
#   568: 'Sneakerheads',
#   567: 'The Book of Sun',
#   565: 'Miss Bala',
#   563: 'The Gambler',
#   558: 'Hotel Transylvania 2',
#   557: 'Alias J.J.',
#   556: 'Tag',
#   554: 'Lost Girls',
#   549: 'The Great Pretender',
#   548: 'First Man',
#   547: 'Status Update',
#   546: 'Shameless',
#   544: 'Suburra: Blood on Rome',
#   540: 'The Plagues of Breslau',
#   538: 'Twilight',
#   533: 'Family Business',
#   529: 'The Dark Tower',
#   526: 'Creed',
#   525: 'American Made',
#   520: 'The Hunger Games: Catching Fire',
#   518: 'Black and Blue',
#   517: 'Matchday: Inside FC Barcelona',
#   516: '2 Guns',
#   514: 'Absurd Planet',
#   513: 'Harry Potter and the Order of the Phoenix',
#   510: 'The Gentlemen',
#   509: 'Annabelle: Creation',
#   508: 'The Epic Tales of Captain Underpants in Space',
#   506: 'Zombieland: Double Tap',
#   505: 'Tall Girl',
#   504: 'Juman',
#   500: 'Peninsula',
#   499: 'Perdida',
#   495: 'The Adjustment Bureau',
#   491: 'Wonder Park',
#   490: 'The Kingdom',
#   489: 'London Has Fallen',
#   487: 'Teenage Mutant Ninja Turtles',
#   486: 'The Last Airbender',
#   482: 'The Swiss Family Robinson: Flone of the Mysterious Island',
#   480: 'The Thundermans',
#   479: 'Proud Mary',
#   476: 'CHiPS',
#   475: 'The Hungover Games',
#   474: 'Jack Whitehall: Travels with My Father',
#   473: 'Papillon',
#   472: 'The Man from U.N.C.L.E.',
#   470: 'State of Play',
#   469: 'Blended',
#   468: 'Avatar: The Last Airbender',
#   467: 'Dr. Stone',
#   466: 'Addicted',
#   465: 'Home Again',
#   461: 'Deliver Us from Evil',
#   460: 'The Little Hours',
#   459: 'Double Jeopardy',
#   458: 'The Fast and the Furious',
#   457: 'Replicas',
#   456: 'Bulbbul',
#   455: 'Honest Candidate',
#   454: 'John Wick: Chapter 3 – Parabellum',
#   449: 'Fierce',
#   447: 'The Shack',
#   446: 'The Bridge Curse',
#   445: 'The Lego Movie',
#   444: 'Home Game',
#   442: 'Journey 2: The Mysterious Island',
#   440: 'Gigantosaurus',
#   438: 'Ghost Ship',
#   437: 'Push',
#   436: 'Fauda',
#   435: 'Rough Night',
#   433: 'The 15:17 to Paris',
#   432: 'The Possession of Hannah Grace',
#   431: 'The Son of Bigfoot',
#   429: 'Identity Thief',
#   427: 'The Maid',
#   426: 'Killers',
#   423: 'Sabotage',
#   422: 'Halloween',
#   421: 'Maradona in Mexico',
#   420: 'After',
#   419: 'Happy Death Day',
#   418: 'Unlocked',
#   416: 'AK vs AK',
#   414: 'Cowboys & Aliens',
#   411: 'Peter Rabbit',
#   409: 'The Guest',
#   408: 'The Office',
#   407: 'Arrow',
#   404: 'A Love to Last',
#   403: 'A Prayer Before Dawn',
#   402: 'F is for Family',
#   401: 'The Players',
#   400: 'Kung Fu Panda 2',
#   398: 'The Lego Movie 2: The Second Part',
#   396: 'Bhaag Beanie Bhaag',
#   395: 'Bleeding Steel',
#   394: 'Inception',
#   393: 'The Innocence Files',
#   388: 'Sugar Rush Christmas',
#   387: 'Dragons Dogma',
#   386: 'Ahiru no Sora',
#   385: 'The Green Mile',
#   384: 'Zodiac',
#   382: 'Doctor John',
#   381: 'White Chicks',
#   380: 'Signs',
#   379: 'Go Ahead',
#   377: 'Masterminds',
#   376: 'The Underclass',
#   374: 'The House with a Clock in Its Walls',
#   372: 'Familiar Wife',
#   370: '100 Things',
#   368: 'Wind River',
#   367: 'Mile 22',
#   366: 'The Boss Baby',
#   364: 'The Valhalla Murders',
#   362: 'Hancock',
#   361: 'Bolívar: Una lucha admirable',
#   360: 'Ala Vaikunthapurramuloo',
#   359: 'Peaky Blinders',
#   358: 'Orange Is the New Black',
#   356: 'Spirit: Stallion of the Cimarron',
#   355: 'No Surrender',
#   354: 'Lady Bird',
#   353: 'Greenleaf',
#   351: 'The Glass Castle',
#   350: 'POKÉMON Detective Pikachu',
#   349: 'The Expanding Universe of Ashley Garcia',
#   348: 'Inheritance',
#   345: 'Dragged Across Concrete',
#   344: 'Four Brothers',
#   343: 'Class Reunion 1.0',
#   342: 'The Smurfs 2',
#   341: 'Spirited Away',
#   340: 'San Andreas',
#   339: 'A Man Apart',
#   338: 'My Christmas Inn',
#   337: 'A Dogs Way Home',
#   336: 'Central Intelligence',
#   334: 'The Next Three Days',
#   333: 'Saturday Night Live Arabia',
#   332: 'Train to Busan',
#   331: 'The Politician',
#   330: 'Aftermath',
#   329: 'ÜberWeihnachten',
#   328: 'Phantom Thread',
#   326: 'Ghosts of Girlfriends Past',
#   325: 'Taken 3',
#   324: 'American Horror Story',
#   323: 'Gotham',
#   322: 'Never Back Down 2: The Beatdown',
#   321: 'Oblivion',
#   318: 'Dérapages',
#   316: 'Capernaum',
#   313: 'Step Up',
#   312: 'Roman J. Israel, Esq.',
#   310: 'Failure to Launch',
#   307: 'Batman v Superman: Dawn of Justice',
#   306: 'Line of Duty',
#   305: 'Kingsman: The Golden Circle',
#   304: 'Exatlon Challenge',
#   303: 'King Shakir',
#   302: 'Godzilla',
#   301: 'Minions',
#   300: 'Cypher',
#   299: 'Connected',
#   298: 'My Father',
#   297: 'Pixels',
#   296: 'War',
#   295: 'Us',
#   294: 'The Best of Me',
#   292: 'Dawsons Creek',
#   290: 'Love on the Spectrum',
#   289: 'Re:ZERO -Starting Life in Another World-',
#   288: 'Black Ballerina',
#   287: 'The Accountant',
#   286: 'Wild Child',
#   284: 'Ženská na vrcholu',
#   283: 'Bee Movie',
#   282: 'Raman Raghav 2.0',
#   281: 'Broken City',
#   279: 'Dragons: Rescue Riders: Huttsgalor Holiday',
#   277: 'R.I.P.D.',
#   276: 'Waco',
#   275: 'Scary Movie 5',
#   273: 'I Want to Get Married',
#   270: 'The Addams Family',
#   269: 'The Judge',
#   268: 'Car Masters: Rust to Riches',
#   267: 'Moneyball',
#   266: 'Grown Ups 2',
#   265: 'The Town',
#   264: 'Poseidon',
#   263: 'Harry Potter and the Deathly Hallows: Part 1',
#   262: 'The Lord of the Skies',
#   261: 'American Psycho',
#   260: 'Cargo',
#   259: 'Why Him?',
#   258: 'Edge of Tomorrow',
#   257: 'Crank',
#   256: 'The Man Standing Next',
#   253: 'Second Act',
#   252: 'Mr. Sunshine',
#   251: 'Constantine',
#   250: '47 Meters Down: Uncaged',
#   248: 'Cloudy with a Chance of Meatballs',
#   247: 'Nanny McPhee and the Big Bang',
#   246: 'Django Unchained',
#   245: 'Exodus: Gods and Kings',
#   244: 'Lara Croft Tomb Raider: The Cradle of Life',
#   243: 'The Legend of Tarzan',
#   242: 'The Hunger Games: Mockingjay - Part 1',
#   241: 'Black Mirror: Bandersnatch',
#   239: 'The Great Wall',
#   238: 'Acts of Violence',
#   237: 'Kosti Byoujanni',
#   236: 'The Founder',
#   235: 'BG: Personal Bodyguard',
#   234: 'Henry Danger',
#   233: 'Miami Vice',
#   232: 'Fast & Furious Presents: Hobbs & Shaw',
#   231: 'La Reina del Sur',
#   230: 'Deep Impact',
#   229: 'Dark Shadows',
#   227: 'Přes prsty',
#   226: 'Gilmore Girls',
#   225: 'Paul',
#   224: 'Que Leones',
#   223: 'Rumor Has It...',
#   222: '47 Ronin',
#   221: 'White Boy Rick',
#   220: 'The Imitation Game',
#   218: '21 Bridges',
#   217: 'The Twilight Saga: Breaking Dawn - Part 2',
#   216: 'Flatliners',
#   215: 'Future World',
#   214: 'Mission: Impossible - Ghost Protocol',
#   213: 'In The Deep',
#   210: 'Knives Out',
#   209: 'The Angry Birds Movie',
#   208: 'Conan the Barbarian',
#   207: 'Inglourious Basterds',
#   206: 'The Tale of Nokdu',
#   205: 'The Prince',
#   204: 'Hulk',
#   203: 'Public Enemies',
#   202: 'Love Happens',
#   201: 'All American',
#   200: 'Back to the Future',
#   199: 'S.W.A.T.: Under Siege',
#   198: 'StarBeam',
#   197: 'Monster-in-Law',
#   196: 'The Scorpion King',
#   195: 'Daylight',
#   194: 'Trauma Center',
#   193: '17 Again',
#   192: 'I See You',
#   191: 'How I Met Your Mother',
#   190: 'Before I Go to Sleep',
#   189: 'Teen Titans Go!',
#   188: 'RocknRolla',
#   187: 'Batman Begins',
#   186: 'The Hangover',
#   185: 'Jupiter Ascending',
#   184: 'Three Kingdoms',
#   183: 'Terminator Genisys',
#   182: 'Annabelle',
#   181: 'Once Upon a Time',
#   180: 'Prison Playbook',
#   179: 'Unknown',
#   178: 'Mean Girls',
#   177: 'The Core',
#   176: 'Transformers: Age of Extinction',
#   175: 'Loco por vos',
#   174: 'Love Likes Coincidences 2',
#   173: 'The Nut Job',
#   172: 'The House',
#   171: 'Lockout',
#   170: 'Now You See Me 2',
#   169: 'Stealth',
#   167: 'Searching for Bobby Fischer',
#   166: 'Alvinnn!!! and The Chipmunks',
#   165: 'Only the Brave',
#   164: 'The Hobbit: An Unexpected Journey',
#   163: 'One Day',
#   162: 'Forgetting Sarah Marshall',
#   161: 'The November Man',
#   160: 'Violet Evergarden: Eternity and the Auto Memory Doll',
#   159: 'The Incredible Story of the Giant Pear',
#   158: 'Live Free or Die Hard',
#   157: 'The 40 Year Old Virgin',
#   156: 'Death Race',
#   155: 'Titanic',
#   154: 'Welcome Home Roscoe Jenkins',
#   153: 'Akira',
#   152: 'Pitbull. Last Dog',
#   151: 'The Twilight Saga: Eclipse',
#   150: 'The Dark Knight Rises',
#   149: 'The Mummy',
#   148: 'St. Vincent',
#   147: 'Twelve Monkeys',
#   146: 'G.I. Joe: The Rise of Cobra',
#   145: '2012',
#   144: 'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   143: 'Animal Kingdom',
#   142: '21',
#   141: 'Harry Potter and the Deathly Hallows: Part 2',
#   140: 'Sleepless',
#   139: 'The Devils Advocate',
#   138: 'The Whole Truth',
#   137: 'X-Large',
#   135: 'Underworld: Evolution',
#   134: 'Click',
#   133: 'Dont Be a Menace to South Central While Drinking Your Juice in the Hood',
#   132: 'Mission: Impossible III',
#   131: 'Shrek',
#   130: 'Castle Rock',
#   129: 'Love Actually',
#   128: 'Into the Storm',
#   127: 'No Country for Old Men',
#   126: 'Ponyo',
#   125: 'Ghost Rider: Spirit of Vengeance',
#   124: 'Fast & Furious',
#   123: 'The Day After Tomorrow',
#   122: 'Rampant',
#   121: 'Van Helsing',
#   120: 'Catwoman',
#   119: 'Hitman',
#   118: 'Derry Girls',
#   117: 'Man of Steel',
#   116: 'The Ruins',
#   115: 'The Revenant',
#   114: 'American Gangster',
#   113: 'This Is 40',
#   112: 'Father of Four: At Sea',
#   111: 'Half Past Dead',
#   110: 'The Help',
#   109: 'Chinese Zodiac',
#   108: 'The Polar Express',
#   107: 'Johnny English',
#   106: 'Arthur Christmas',
#   105: 'The Green Hornet',
#   104: 'Doom',
#   103: 'Underworld: Rise of the Lycans',
#   102: 'The Cabin with Bert Kreischer',
#   101: 'The Matrix',
#   100: 'The Mortal Instruments: City of Bones',
#   99: 'Knock Knock',
#   98: 'True Grit',
#   97: 'Kung Fu Panda',
#   96: 'School of Rock',
#   95: 'Dumplin',
#   94: 'Final Destination 5',
#   93: 'Gun City',
#   92: 'Cosy Dens',
#   91: 'Miss Congeniality',
#   90: 'Event Horizon',
#   89: 'Easy A',
#   88: 'The Amazing Spider-Man 2',
#   87: 'The Edge of Seventeen',
#   86: 'The Frozen Ground',
#   85: 'How to Lose a Guy in 10 Days',
#   84: 'S.W.A.T.',
#   83: 'Police Academy',
#   82: 'No Strings Attached',
#   81: 'Salt',
#   80: 'Little Fockers',
#   79: 'The Perfect Storm',
#   78: 'Sherlock Holmes',
#   77: 'The Transporter',
#   76: 'Road to Perdition',
#   75: 'Iron Man 3',
#   74: 'Antigang',
#   73: 'Rango',
#   72: 'Killer Elite',
#   71: 'Real Steel',
#   70: 'Stardust',
#   69: 'Terminator Salvation',
#   68: 'Skin',
#   67: 'Munich',
#   66: 'Hall Pass',
#   65: 'Layer Cake',
#   64: 'Zoom',
#   63: 'Interstellar',
#   62: 'The Break-Up',
#   61: 'The Hangover Part III',
#   60: 'The Lord of the Rings: The Return of the King',
#   59: 'Madagascar: Escape 2 Africa',
#   58: 'Tokyo Ghoul',
#   57: 'Colombiana',
#   56: 'The Rite',
#   55: 'The Prestige',
#   54: 'House at the End of the Street',
#   53: 'Toy Story 3',
#   52: 'Arthur and the Invisibles',
#   51: 'Crazy, Stupid, Love.',
#   50: 'Wrath of the Titans',
#   49: 'RED 2',
#   48: 'Into the Wild',
#   47: 'The Mummy: Tomb of the Dragon Emperor',
#   46: 'Marie Antoinette',
#   45: 'Rambo',
#   44: 'Non-Stop',
#   43: 'The Heat',
#   42: 'The Bourne Legacy',
#   41: 'Yogi Bear',
#   40: 'Seventh Son',
#   39: 'Thor: The Dark World',
#   38: 'Red Riding Hood',
#   37: 'Happy Gilmore',
#   36: 'Hercules',
#   35: 'Elf',
#   34: 'Super 8',
#   33: 'Detective Conan: Dimensional Sniper',
#   32: 'The Last Samurai',
#   31: 'The Day the Earth Stood Still',
#   30: 'The Family',
#   29: 'Warrior',
#   28: 'Road Trip',
#   27: 'Olympus Has Fallen',
#   26: 'Funny People',
#   25: '300',
#   24: 'Never Back Down',
#   23: 'The Drop',
#   22: 'Kick-Ass',
#   21: 'The Karate Kid',
#   20: 'The Man with the Iron Fists',
#   19: 'Clash of the Titans',
#   18: 'Ghost Rider',
#   17: 'Bridesmaids',
#   16: 'Cobra',
#   15: 'Cop Out',
#   14: 'The Expendables',
#   13: 'A Knights Tale',
#   12: 'John Q',
#   11: 'Elysium',
#   10: 'Rio',
#   9: 'Fury',
#   8: 'The Avengers',
#   7: 'White House Down',
#   6: 'Hot Fuzz',
#   5: 'Captain Phillips',
#   4: 'Divergent',
#   3: 'Wild Card',
#   2: 'Tangled',
#   1: 'Riddick'}}

# %%
net_counter = Counter(df_net.TITLE)

# %%
net_counter
# Out:
# Counter({'The Queens Gambit': 1,
#          '365 Days': 1,
#          'Emily in Paris': 1,
#          'Lucifer': 1,
#          'The Umbrella Academy': 1,
#          'Money Heist': 1,
#          'Dark Desire': 1,
#          'The Crown': 1,
#          'Friends': 1,
#          'Enola Holmes': 1,
#          'Yo soy Betty la fea': 1,
#          'The Christmas Chronicles: Part Two': 1,
#          'Ratched': 1,
#          'Holidate': 1,
#          'Pablo Escobar, The Drug Lord': 1,
#          'Dark': 1,
#          'The Last Dance': 1,
#          'The Old Guard': 1,
#          'Snowpiercer': 1,
#          'The Social Dilemma': 1,
#          '100 Dias Para Enamorarnos': 1,
#          'Project Power': 1,
#          'The Haunting of Bly Manor': 1,
#          'The SpongeBob Movie: Sponge on the Run': 1,
#          'Cursed': 1,
#          'The Kissing Booth 2': 1,
#          'Cobra Kai': 1,
#          'Extraction': 1,
#          'Its Okay to Not Be Okay': 1,
#          'Paw Patrol': 1,
#          'Locked Up': 1,
#          'Modern Family': 1,
#          'Hubie Halloween': 1,
#          'Warrior Nun': 1,
#          'Star Trek: Discovery': 1,
#          'Too Hot to Handle': 1,
#          'Away': 1,
#          'Barbaren': 1,
#          'Virgin River': 1,
#          'Unsolved Mysteries': 1,
#          'Tiny Pretty Things': 1,
#          'CoComelon': 1,
#          'Over the Moon': 1,
#          'A California Christmas': 1,
#          'Start-Up': 1,
#          '13 Reasons Why': 1,
#          'The Devil All the Time': 1,
#          'Work It': 1,
#          'Love, Guaranteed': 1,
#          'American Murder: The Family Next Door': 1,
#          'Feel the Beat': 1,
#          'Rick and Morty': 1,
#          'The Christmas Chronicles': 1,
#          'Jurassic World: Camp Cretaceous': 1,
#          'The Princess Switch: Switched Again': 1,
#          'White Lines': 1,
#          'The King: Eternal Monarch': 1,
#          'The 100': 1,
#          'The Grinch': 1,
#          '#Alive': 1,
#          'Operation Christmas Drop': 1,
#          'Her Mothers Killer': 1,
#          'Dynasty': 1,
#          'The Boss Baby: Back in Business': 1,
#          'The Sleepover': 1,
#          'Space Force': 1,
#          'Riverdale': 1,
#          'The Wrong Missy': 1,
#          'Rebecca': 1,
#          'Bronx': 1,
#          'Tiger King: Murder, Mayhem and Madness': 1,
#          'The Order': 1,
#          'Good Girls': 1,
#          'Ozark': 1,
#          'The Midnight Sky': 1,
#          'Record of Youth': 1,
#          'Amar y Vivir': 1,
#          'How the Grinch Stole Christmas': 1,
#          'Pasión de gavilanes': 1,
#          'The Babysitter: Killer Queen': 1,
#          'Floor is Lava': 1,
#          'Mosul': 1,
#          'The Paramedic': 1,
#          'The Platform': 1,
#          'To the Lake': 1,
#          'The Mess You Leave Behind': 1,
#          'Never Have I Ever': 1,
#          'The Kissing Booth': 1,
#          'MILF': 1,
#          'Skyscraper': 1,
#          'Outer Banks': 1,
#          'The Blacklist': 1,
#          'Desperados': 1,
#          'The Last Days of American Crime': 1,
#          'The Beast': 1,
#          'Jeffrey Epstein: Filthy Rich': 1,
#          'The Seven Deadly Sins': 1,
#          'Despicable Me 2': 1,
#          'Eurovision Song Contest: The Story of Fire Saga': 1,
#          'The Willoughbys': 1,
#          'Dangerous Lies': 1,
#          'Jingle Jangle: A Christmas Journey': 1,
#          'Crash Landing on You': 1,
#          'Bridgerton': 1,
#          'Lost Bullet': 1,
#          'Prison Break': 1,
#          'Unorthodox': 1,
#          '6 Underground': 1,
#          'Jurassic World: Fallen Kingdom': 1,
#          'The Emoji Movie': 1,
#          'How to Get Away with Murder': 1,
#          'David Attenborough: A Life on Our Planet': 1,
#          'The Prom': 1,
#          'Toy Boy': 1,
#          'The Sinner': 1,
#          'Resurrection: Ertugrul': 1,
#          'Dash & Lily': 1,
#          'Demon Slayer: Kimetsu no Yaiba': 1,
#          'Enemigo íntimo': 1,
#          'What Men Want': 1,
#          'We Can Be Heroes': 1,
#          'Down to Earth with Zac Efron': 1,
#          'The Trial of the Chicago 7': 1,
#          'Was It Love': 1,
#          'Sweet Home': 1,
#          'Hospital Playlist': 1,
#          'Selena: The Series': 1,
#          'Wonder': 1,
#          'Elite': 1,
#          'Worlds Most Wanted': 1,
#          'Dead to Me': 1,
#          'Fatal Affair': 1,
#          'Secrets of the Saqqara Tomb': 1,
#          'Queen of the South': 1,
#          'An Easy Girl': 1,
#          'Blood of Zeus': 1,
#          'Ava': 1,
#          'The Witcher': 1,
#          'Love. Wedding. Repeat': 1,
#          'Despicable Me': 1,
#          'Alice in Borderland': 1,
#          'Santana': 1,
#          'A Babysitters Guide to Monster Hunting': 1,
#          'The Secret: Dare to Dream': 1,
#          'The Half of It': 1,
#          'La Révolution': 1,
#          'Johnny English Strikes Again': 1,
#          'Big Mouth': 1,
#          'Money Heist: The Phenomenon': 1,
#          'The Call': 1,
#          'Fifty Shades Freed': 1,
#          'Hoops': 1,
#          'Aquaman': 1,
#          'The Rain': 1,
#          'Da 5 Bloods': 1,
#          'Pets United': 1,
#          'El Dragón: Return of a Warrior': 1,
#          'Instant Family': 1,
#          'How to Sell Drugs Online (Fast)': 1,
#          'Venom': 1,
#          'Harry Potter and the Philosophers Stone': 1,
#          'Mystic Pop-Up Bar': 1,
#          'Malibu Rescue: The Next Wave': 1,
#          'Miracle in Cell No. 7': 1,
#          'BLACKPINK: Light Up the Sky': 1,
#          'Family Guy': 1,
#          'The Last Kingdom': 1,
#          'The Business of Drugs': 1,
#          'Young Wallander': 1,
#          'Trinkets': 1,
#          'Fear City: New York vs The Mafia': 1,
#          'Grizzy & the Lemmings': 1,
#          'Alien Worlds': 1,
#          'If Anything Happens I Love You': 1,
#          'Time Trap': 1,
#          'Freud': 1,
#          'Furious 7': 1,
#          'Freaks – Youre One of Us': 1,
#          'Stolen Away': 1,
#          'Code 8': 1,
#          'Bimilui Soop': 1,
#          'Baby': 1,
#          'Greys Anatomy': 1,
#          'Animal Crackers': 1,
#          'Into the Night': 1,
#          'A Million Ways to Die in the West': 1,
#          'Dad Wanted': 1,
#          'The World of the Married': 1,
#          'The Equalizer 2': 1,
#          'Justice League': 1,
#          'Rose Island': 1,
#          'The Meg': 1,
#          'Deadly Class': 1,
#          'Get Organized with The Home Edit': 1,
#          'The Purge: Anarchy': 1,
#          'Dirty John': 1,
#          'The Great Heist': 1,
#          'The Flash': 1,
#          'Vikings': 1,
#          'The Life Ahead': 1,
#          'Midnight at the Magnolia': 1,
#          'Just Another Christmas': 1,
#          'Night School': 1,
#          'Biohackers': 1,
#          'Coffee & Kareem': 1,
#          'Private Lives': 1,
#          'Seriously Single': 1,
#          'Suits': 1,
#          'The F**k-It List': 1,
#          'The Barrier': 1,
#          'Home for Christmas': 1,
#          'American Assassin': 1,
#          'Murder Mystery': 1,
#          'Focus': 1,
#          'The Boss Baby: Get That Baby!': 1,
#          'Hotel Transylvania 3: Summer Vacation': 1,
#          'The Star': 1,
#          'Mortal Engines': 1,
#          'Spider-Man: Homecoming': 1,
#          'The Ripper': 1,
#          'Youve Got This': 1,
#          'In the Heart of the Sea': 1,
#          'Christmas Made to Order': 1,
#          'Sweet Magnolias': 1,
#          'Itaewon Class': 1,
#          'Control Z': 1,
#          'Brooklyn Nine-Nine': 1,
#          'Ludo': 1,
#          'Spider-Man: Into the Spider-Verse': 1,
#          'Selling Sunset': 1,
#          'Bumblebee': 1,
#          'High Score': 1,
#          'Paranormal': 1,
#          'The End of Paradise': 1,
#          'Spenser Confidential': 1,
#          'History 101': 1,
#          'The Alienist': 1,
#          'Rampage': 1,
#          'Mission: Impossible - Fallout': 1,
#          'The Holiday': 1,
#          'ariana grande: excuse me, i love you': 1,
#          'The Princess Switch': 1,
#          'Jane the Virgin': 1,
#          'Dont Listen': 1,
#          'Harry Potter and the Chamber of Secrets': 1,
#          'The Walking Dead': 1,
#          'The First Purge': 1,
#          'Better Call Saul': 1,
#          'Geostorm': 1,
#          'Safe House': 1,
#          'The Main Event': 1,
#          'The Baby-Sitters Club': 1,
#          'Bad Boys for Life': 1,
#          'Double World': 1,
#          'Parker': 1,
#          'Kärlek & Anarki': 1,
#          'Schitts Creek': 1,
#          'Valeria': 1,
#          'All Together Now': 1,
#          'Jumanji: The Next Level': 1,
#          'A Suitable Boy': 1,
#          'Hollywood': 1,
#          'A Star is Born': 1,
#          'Undercover': 1,
#          'Tammy': 1,
#          'Anne with an E': 1,
#          'The Gift': 1,
#          'The Woods': 1,
#          'Hillbilly Elegy': 1,
#          'Siberia': 1,
#          'Behzat Ç.': 1,
#          'Intuition': 1,
#          'A Simple Favor': 1,
#          'Earth and Blood': 1,
#          'Chica Vampiro': 1,
#          'Sex Education': 1,
#          'The Uncanny Counter': 1,
#          'Escape Plan': 1,
#          'Teenage Bounty Hunters': 1,
#          'Bloodshot': 1,
#          'Pacific Rim: Uprising': 1,
#          'Lucy': 1,
#          'Baby Driver': 1,
#          'Do Do Sol Sol La La Sol': 1,
#          'The Good Place': 1,
#          'Cadaver': 1,
#          'Nobody Sleeps In The Woods Tonight': 1,
#          'Cinderela Pop': 1,
#          'Crazy Rich Asians': 1,
#          'Despicable Me 3': 1,
#          'Scooby-Doo 2: Monsters Unleashed': 1,
#          'Ready Player One': 1,
#          'Death to 2020': 1,
#          'Norbit': 1,
#          'The Big Show Show': 1,
#          'Dare Me': 1,
#          'Ted': 1,
#          'It': 1,
#          'Wasp Network': 1,
#          'Wizards: Tales of Arcadia': 1,
#          'All Day and a Night': 1,
#          'Glow Up: Britains Next Make-Up Star': 1,
#          'Indian Matchmaking': 1,
#          'Oceans 8': 1,
#          'Alexa & Katie': 1,
#          '12 Strong': 1,
#          'The Fabulous Lives of Bollywood Wives': 1,
#          'Bad Boy Billionaires: India': 1,
#          'Cable Girls': 1,
#          'The Letter for the King': 1,
#          'How to Train Your Dragon: The Hidden World': 1,
#          'Wonder Woman': 1,
#          'The Fall': 1,
#          'Reply 1988': 1,
#          'Becoming': 1,
#          'Princess Sarah': 1,
#          'One Piece': 1,
#          'The Occupant': 1,
#          'Sniper: Ultimate Kill': 1,
#          'Ride Along': 1,
#          'The Liberator': 1,
#          'Torbaaz': 1,
#          'Blockers': 1,
#          'Inside the Worlds Toughest Prisons': 1,
#          'Summertime': 1,
#          'Ginny Weds Sunny': 1,
#          'Ethos': 1,
#          'King Arthur: Legend of the Sword': 1,
#          'Offering to the Storm': 1,
#          'Have a Good Trip: Adventures in Psychedelics': 1,
#          'Johnny English Reborn': 1,
#          'Adú': 1,
#          'Gemini Man': 1,
#          'Harry Potter and the Prisoner of Azkaban': 1,
#          'Unfriended: Dark Web': 1,
#          'Upgrade': 1,
#          'Vacation': 1,
#          'Savages': 1,
#          'The Hater': 1,
#          'After Life': 1,
#          'Fast Five': 1,
#          'Im Thinking of Ending Things': 1,
#          'The Crimes That Bind': 1,
#          'Tom and Jerry: The Movie': 1,
#          'The Nun': 1,
#          'The Angry Birds Movie 2': 1,
#          'Chiquititas': 1,
#          'Alguien tiene que morir': 1,
#          'The Silence of the Marsh': 1,
#          'The Decline': 1,
#          'The Lovebirds': 1,
#          'Space Jam': 1,
#          'American Sniper': 1,
#          'Goblin': 1,
#          'Fantastic Beasts: The Crimes of Grindelwald': 1,
#          'Mercury Rising': 1,
#          'The Losers': 1,
#          'Neighbors': 1,
#          'Mismatched': 1,
#          'Peppa Pig': 1,
#          'Marcella': 1,
#          'The Worst Witch': 1,
#          'Curon': 1,
#          'Close Enough': 1,
#          'SpongeBob SquarePants': 1,
#          'Battleship': 1,
#          'Blood Diamond': 1,
#          'Million Dollar Beach House': 1,
#          'Dunkirk': 1,
#          'Truth or Dare': 1,
#          'What We Wanted': 1,
#          'La Piloto': 1,
#          'The Impossible': 1,
#          'The Protector': 1,
#          'Wanted': 1,
#          'The 2nd': 1,
#          'Hi Bye, Mama!': 1,
#          'Charlies Angels': 1,
#          'The Lorax': 1,
#          'Oloture': 1,
#          'The Mask': 1,
#          'Blade Runner 2049': 1,
#          'After We Collided': 1,
#          'Community': 1,
#          'Citation': 1,
#          'Julie and the Phantoms': 1,
#          'Stateless': 1,
#          'No Manches Frida': 1,
#          'Serious Men': 1,
#          'Jumanji: Welcome to the Jungle': 1,
#          'A Quiet Place': 1,
#          'Dolly Kitty and Those Shining Stars': 1,
#          'Athlete A': 1,
#          'Parasite': 1,
#          'Fire Force': 1,
#          'His House': 1,
#          'From Prada to Nada': 1,
#          'Doomsday': 1,
#          '(Un)Well': 1,
#          'Sniper: Legacy': 1,
#          'The Queen of Flow': 1,
#          'Gunjan Saxena: The Kargil Girl': 1,
#          'Howls Moving Castle': 1,
#          'Joker': 1,
#          'Rosario Tijeras': 1,
#          'Grown Ups': 1,
#          'Rich in Love': 1,
#          'New Girl': 1,
#          '18 Presents': 1,
#          'Room 2806: The Accusation': 1,
#          'Ultras': 1,
#          'Fantasy Island': 1,
#          'The Invention of Lying': 1,
#          'The Stand In': 1,
#          'Charlie and the Chocolate Factory': 1,
#          'The Change-Up': 1,
#          'Alpha': 1,
#          'The Intern': 1,
#          'Dream Home Makeover': 1,
#          'Betty en NY': 1,
#          'The Wolf of Wall Street': 1,
#          'Be Careful What You Wish For': 1,
#          'A Whisker Away': 1,
#          'Jack Reacher': 1,
#          'I Love You, Stupid': 1,
#          'Class of 83': 1,
#          'Death Wish': 1,
#          'Get Hard': 1,
#          '8 Mile': 1,
#          'Going in Style': 1,
#          'Hes Out There': 1,
#          'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)': 1,
#          'Father Figures': 1,
#          'Whats Wrong with Secretary Kim': 1,
#          'Love is Blind': 1,
#          'Shazam!': 1,
#          'Contagion': 1,
#          'The Legend of Korra': 1,
#          'Cuties': 1,
#          'Masaba Masaba': 1,
#          'Den of Thieves': 1,
#          'Recep Ivedik 6': 1,
#          'Sicario: Day Of The Soldado': 1,
#          'The Mule': 1,
#          'The SpongeBob SquarePants Movie': 1,
#          'Keeping Up with the Kardashians': 1,
#          'Raat Akeli Hai': 1,
#          'Self Made: Inspired by the Life of Madam C.J. Walker': 1,
#          'My Hero Academia': 1,
#          'The Irishman': 1,
#          'Life of the Party': 1,
#          'Robin Hood': 1,
#          'Run All Night': 1,
#          'Jack Ryan: Shadow Recruit': 1,
#          'Coronavirus, Explained': 1,
#          'The Duchess': 1,
#          'Slender Man': 1,
#          'Cloudy with a Chance of Meatballs 2': 1,
#          'Think Like a Dog': 1,
#          'Unknown Origins': 1,
#          'The Big Bang Theory': 1,
#          'G.I. Joe: Retaliation': 1,
#          'Los favoritos de Midas': 1,
#          'Baki': 1,
#          'Attack on Titan': 1,
#          'Assassins Creed': 1,
#          'Outlander': 1,
#          'Instructions Not Included': 1,
#          'The SpongeBob Movie: Sponge Out of Water': 1,
#          'Mamma Mia: Here We Go Again!': 1,
#          'The Foreigner': 1,
#          'The Legacy of the Bones': 1,
#          'The Victims Game': 1,
#          'Fast and Furious Spy Racers': 1,
#          'Breaking In': 1,
#          'Faster': 1,
#          'Due Date': 1,
#          'Jujutsu Kaisen': 1,
#          'We Are the Champions': 1,
#          'Little Italy': 1,
#          'It Chapter Two': 1,
#          'Harry Potter and the Half-Blood Prince': 1,
#          'The House of Flowers': 1,
#          'Carmel: Who Killed Maria Marta?': 1,
#          'Mary Queen of Scots': 1,
#          'The Ninth Gate': 1,
#          'H': 1,
#          'Sing': 1,
#          'John Wick: Chapter Two': 1,
#          'Sergio': 1,
#          'Latte and the Magic Waterstone': 1,
#          '300: Rise of an Empire': 1,
#          'The School Nurse Files': 1,
#          'Challenger: The Final Flight': 1,
#          'Scooby-Doo': 1,
#          'O Vendedor de Sonhos': 1,
#          'Mohamed Hussein': 1,
#          'Contraband': 1,
#          'El Testamento de la Abuela': 1,
#          'Pride & Prejudice': 1,
#          'Overlord': 1,
#          'The Bureau of Magical Things': 1,
#          'Extracurricular': 1,
#          'Little Women': 1,
#          'The Devils Mark': 1,
#          'The Last Witch Hunter': 1,
#          'Harry Potter and the Goblet of Fire': 1,
#          'Smallfoot': 1,
#          'Anna': 1,
#          'Green Lantern': 1,
#          'Trial 4': 1,
#          'Cómo Matar a un Esposo Muerto': 1,
#          'Independence Day: Resurgence': 1,
#          'The Dark Knight': 1,
#          'Tears of the Sun': 1,
#          'The Hunger Games': 1,
#          'The Snowman': 1,
#          'Couples Retreat': 1,
#          'RuPauls Drag Race All Stars': 1,
#          'The Suit': 1,
#          'Criminal: UK': 1,
#          'Peppermint': 1,
#          'X-Men: Apocalypse': 1,
#          'Creed II': 1,
#          'Little': 1,
#          'Deep Blue Sea': 1,
#          'Fearless': 1,
#          'Fuller House': 1,
#          'RuPauls Drag Race': 1,
#          'Mission: Impossible - Rogue Nation': 1,
#          'Chefs Table: BBQ': 1,
#          'Paava Kadhaigal': 1,
#          'Heart Signal': 1,
#          'Rust Valley Restorers': 1,
#          'The Binding': 1,
#          'Arkansas': 1,
#          'Solomon Kane': 1,
#          'Unforgettable': 1,
#          'Mighty Express': 1,
#          'Eltilerin Savaşi': 1,
#          'The Garfield Show': 1,
#          'The Adventures of Sharkboy and Lavagirl': 1,
#          'The Little Rascals': 1,
#          'Notes for My Son': 1,
#          'Happy New Year': 1,
#          'The Spy Who Dumped Me': 1,
#          'The Thieves': 1,
#          'Diana: In Her Own Words': 1,
#          'The Tuxedo': 1,
#          'Boys Over Flowers': 1,
#          'Monopoly (Bank Of Luck)': 1,
#          'Game Night': 1,
#          'The Italian Job': 1,
#          'Miss India': 1,
#          'Haikyu!!': 1,
#          'Under the Riccione Sun': 1,
#          'Shawn Mendes: In Wonder': 1,
#          'World War Z': 1,
#          'Escape Room': 1,
#          'Kidnap': 1,
#          'Emerson Heights': 1,
#          'Mad Max: Fury Road': 1,
#          'Hells Kitchen': 1,
#          'Pitch Perfect 3': 1,
#          'Downsizing': 1,
#          'Reality Z': 1,
#          'Time to Hunt': 1,
#          'Christmas Under Wraps': 1,
#          'Girls Trip': 1,
#          'The Fate of the Furious': 1,
#          'Murder to Mercy: The Cyntoia Brown Story': 1,
#          'Shooter': 1,
#          'Barbie: Princess Adventure': 1,
#          'Fist Fight': 1,
#          'Anelka: Misunderstood': 1,
#          'Unbroken': 1,
#          'Sneakerheads': 1,
#          'The Book of Sun': 1,
#          'Miss Bala': 1,
#          'Alien Xmas': 1,
#          'Love 101': 1,
#          'Gods of Egypt': 1,
#          'The Gambler': 1,
#          'Hotel Transylvania 2': 1,
#          'Alias J.J.': 1,
#          'BREAK IT ALL: The History of Rock in Latin America': 1,
#          'Tag': 1,
#          'Lost Girls': 1,
#          'The Great Pretender': 1,
#          'First Man': 1,
#          'Status Update': 1,
#          'The Equalizer': 1,
#          'Shameless': 1,
#          'Street Food': 1,
#          'Suburra: Blood on Rome': 1,
#          'The Plagues of Breslau': 1,
#          'Twilight': 1,
#          'Family Business': 1,
#          'The Dark Tower': 1,
#          'Creed': 1,
#          'American Made': 1,
#          'The Hunger Games: Catching Fire': 1,
#          'Black and Blue': 1,
#          'Malang': 1,
#          'Matchday: Inside FC Barcelona': 1,
#          '2 Guns': 1,
#          'Absurd Planet': 1,
#          'The Blue Elephant Part 2': 1,
#          'A-X-L': 1,
#          'Harry Potter and the Order of the Phoenix': 1,
#          'The Gentlemen': 1,
#          'Happy Death Day 2U': 1,
#          'Annabelle: Creation': 1,
#          'The American Barbecue Showdown': 1,
#          'The Epic Tales of Captain Underpants in Space': 1,
#          'Zombieland: Double Tap': 1,
#          'Tall Girl': 1,
#          'Juman': 1,
#          'Peninsula': 1,
#          'Perdida': 1,
#          'The Adjustment Bureau': 1,
#          'La Línea: La sombra del narco': 1,
#          'Wonder Park': 1,
#          'Rising High': 1,
#          'The Kingdom': 1,
#          'Rayyah El Madame': 1,
#          'London Has Fallen': 1,
#          'Saving Private Ryan': 1,
#          'Fast & Furious 6': 1,
#          'Teenage Mutant Ninja Turtles': 1,
#          'Miss Peregrines Home for Peculiar Children': 1,
#          'The Last Airbender': 1,
#          'The Swiss Family Robinson: Flone of the Mysterious Island': 1,
#          'Goedam': 1,
#          'The Thundermans': 1,
#          'Proud Mary': 1,
#          'CHiPS': 1,
#          'Angelas Christmas Wish': 1,
#          'Godzilla: King of the Monsters': 1,
#          'The Hungover Games': 1,
#          'Mr. Bean: The Animated Series': 1,
#          'Rocketman': 1,
#          'A Bad Moms Christmas': 1,
#          'Jack Whitehall: Travels with My Father': 1,
#          'Papillon': 1,
#          'The Man from U.N.C.L.E.': 1,
#          'Hunter Killer': 1,
#          'State of Play': 1,
#          'Fifty Shades Darker': 1,
#          'Blended': 1,
#          'Avatar: The Last Airbender': 1,
#          'Dr. Stone': 1,
#          'John Henry': 1,
#          'Addicted': 1,
#          'Workin Moms': 1,
#          'Home Again': 1,
#          'Deliver Us from Evil': 1,
#          'The Little Hours': 1,
#          'Grand Army': 1,
#          'Mighty Little Bheem': 1,
#          'Double Jeopardy': 1,
#          'The Fast and the Furious': 1,
#          'Replicas': 1,
#          'El tamano si importa': 1,
#          'Bulbbul': 1,
#          'Honest Candidate': 1,
#          'John Wick: Chapter 3 – Parabellum': 1,
#          'Fierce': 1,
#          'The Shack': 1,
#          'Sister, Sister': 1,
#          'The Bridge Curse': 1,
#          'The Lego Movie': 1,
#          'Home Game': 1,
#          'Al-Khawagas Dilemma': 1,
#          'Gifted': 1,
#          'Kong: Skull Island': 1,
#          'Journey 2: The Mysterious Island': 1,
#          'Gigantosaurus': 1,
#          'The Method': 1,
#          'Atomic Blonde': 1,
#          'Ghost Ship': 1,
#          'Push': 1,
#          'Fauda': 1,
#          'Unlucky Ploy': 1,
#          'Girl from Nowhere': 1,
#          'Blindspot': 1,
#          'Rough Night': 1,
#          'The 15:17 to Paris': 1,
#          'The Possession of Hannah Grace': 1,
#          'Kings of JoBurg': 1,
#          'Japan Sinks: 2020': 1,
#          'The Son of Bigfoot': 1,
#          'The Pocket Hercules Naim': 1,
#          'Sons of Anarchy': 1,
#          'Identity Thief': 1,
#          'The Maid': 1,
#          'Miami Bici': 1,
#          'Killers': 1,
#          'Sabotage': 1,
#          'Halloween': 1,
#          'Maradona in Mexico': 1,
#          'Pharaohs War': 1,
#          'Magnetic': 1,
#          'After': 1,
#          'Dolly Parton’s Christmas on the Square': 1,
#          'The Haunting of Hill House': 1,
#          'Happy Death Day': 1,
#          'Unlocked': 1,
#          'AK vs AK': 1,
#          'Cowboys & Aliens': 1,
#          'Peter Rabbit': 1,
#          'Caliphate': 1,
#          'Daddys Home 2': 1,
#          'Sugar Rush': 1,
#          'The Guest': 1,
#          'Queer Eye': 1,
#          'The Girl in the Spiders Web': 1,
#          'The Office': 1,
#          'Arrow': 1,
#          'A Love to Last': 1,
#          'One-Way to Tomorrow': 1,
#          'A Prayer Before Dawn': 1,
#          'F is for Family': 1,
#          'The Players': 1,
#          'Trash Truck': 1,
#          'Kung Fu Panda 2': 1,
#          'Gogglebox': 1,
#          'The Playbook': 1,
#          'The Lego Movie 2: The Second Part': 1,
#          'The Claus Family': 1,
#          'Bhaag Beanie Bhaag': 1,
#          'Debt Collectors': 1,
#          'Bleeding Steel': 1,
#          'Nothing But Thirty': 1,
#          '5Gang: A different kind of Christmas': 1,
#          'Inception': 1,
#          'The Innocence Files': 1,
#          'Sugar Rush Christmas': 1,
#          'Dragons Dogma': 1,
#          'Ahiru no Sora': 1,
#          'I Feel Pretty': 1,
#          'The Green Mile': 1,
#          'Blood & Water': 1,
#          'Pandemic: How to Prevent an Outbreak': 1,
#          'Escape Plan 2: Hades': 1,
#          'Zodiac': 1,
#          'Doctor John': 1,
#          'White Chicks': 1,
#          'Mamas Boy': 1,
#          'Signs': 1,
#          'Go Ahead': 1,
#          'Masterminds': 1,
#          'Green Zone': 1,
#          'The Underclass': 1,
#          'The House with a Clock in Its Walls': 1,
#          'Familiar Wife': 1,
#          'Klaus': 1,
#          '100 Things': 1,
#          'High & Low: The Worst': 1,
#          'Son Of Adam': 1,
#          'Wind River': 1,
#          'So Much Love to Give': 1,
#          'Rugal': 1,
#          'Mile 22': 1,
#          'The Boss Baby': 1,
#          'The Valhalla Murders': 1,
#          'Love Aaj Kal': 1,
#          'Hancock': 1,
#          'Twogether': 1,
#          'Bolívar: Una lucha admirable': 1,
#          'Jak zostałem gangsterem. Historia prawdziwa': 1,
#          'Ala Vaikunthapurramuloo': 1,
#          'Angel Has Fallen': 1,
#          'Peaky Blinders': 1,
#          'Orange Is the New Black': 1,
#          'Spirit: Stallion of the Cimarron': 1,
#          'Bom Dia, Verônica': 1,
#          'No Surrender': 1,
#          'Lady Bird': 1,
#          'Searching': 1,
#          'Norsemen': 1,
#          'Greenleaf': 1,
#          'Lovestruck in the City': 1,
#          'Parasyte -the maxim-': 1,
#          'The Glass Castle': 1,
#          'POKÉMON Detective Pikachu': 1,
#          'The Expanding Universe of Ashley Garcia': 1,
#          'Inheritance': 1,
#          'Dragged Across Concrete': 1,
#          'Four Brothers': 1,
#          'Class Reunion 1.0': 1,
#          'The Smurfs 2': 1,
#          'The Babysitter': 1,
#          'Spirited Away': 1,
#          'San Andreas': 1,
#          'Goosebumps 2: Haunted Halloween': 1,
#          'A Man Apart': 1,
#          'My Christmas Inn': 1,
#          'A Dogs Way Home': 1,
#          'Central Intelligence': 1,
#          'The Next Three Days': 1,
#          'I AM A KILLER: RELEASED': 1,
#          'Saturday Night Live Arabia': 1,
#          'Train to Busan': 1,
#          'The Politician': 1,
#          'The Search': 1,
#          'Aftermath': 1,
#          'ÜberWeihnachten': 1,
#          'Phantom Thread': 1,
#          'Ghosts of Girlfriends Past': 1,
#          'Taken 3': 1,
#          'Best of Phua Chu Kang Pte Ltd': 1,
#          'American Horror Story': 1,
#          'Gotham': 1,
#          'BlacKkKlansman': 1,
#          'The Secret Life of Pets': 1,
#          'Never Back Down 2: The Beatdown': 1,
#          'Mechanic: Resurrection': 1,
#          'Now You See Me': 1,
#          'Oblivion': 1,
#          'Dérapages': 1,
#          'Capernaum': 1,
#          'Step Up': 1,
#          'Bayi Toplantisi': 1,
#          'Roman J. Israel, Esq.': 1,
#          'Failure to Launch': 1,
#          'The Twelve': 1,
#          'Batman v Superman: Dawn of Justice': 1,
#          'Your Name Engraved Herein': 1,
#          'Suicide Squad': 1,
#          'Line of Duty': 1,
#          'Pup Academy': 1,
#          'Kingsman: The Golden Circle': 1,
#          'Exatlon Challenge': 1,
#          'King Shakir': 1,
#          'Free Willy': 1,
#          'Were the Millers': 1,
#          'Godzilla': 1,
#          'My Octopus Teacher': 1,
#          'Minions': 1,
#          'Narcos': 1,
#          'Cypher': 1,
#          'Connected': 1,
#          'Once Upon a Time in Hollywood': 1,
#          'My Father': 1,
#          'mother!': 1,
#          'Pixels': 1,
#          'Dr. Seuss The Cat in the Hat': 1,
#          'Mr. Peabody & Sherman': 1,
#          'War': 1,
#          'Bad Genius The Series': 1,
#          'ARASHIs Diary -Voyage-': 1,
#          'Us': 1,
#          'Pet Sematary': 1,
#          'The Best of Me': 1,
#          'U Motherbaker': 1,
#          'Flavours of Romania': 1,
#          'Dawsons Creek': 1,
#          'Love on the Spectrum': 1,
#          'Terrace House: Tokyo 2019-2020': 1,
#          'Re:ZERO -Starting Life in Another World-': 1,
#          'Black Ballerina': 1,
#          'The Accountant': 1,
#          'Low Season': 1,
#          'Love Island Australia': 1,
#          'Trolls': 1,
#          'Wild Child': 1,
#          'Ženská na vrcholu': 1,
#          'Zengo': 1,
#          'Friend Zone': 1,
#          'Doctor Sleep': 1,
#          'Turbo': 1,
#          'Bee Movie': 1,
#          'Raman Raghav 2.0': 1,
#          'The Lost Husband': 1,
#          'High Seas': 1,
#          'Broken City': 1,
#          'Dragons: Rescue Riders: Huttsgalor Holiday': 1,
#          'R.I.P.D.': 1,
#          'Waco': 1,
#          'Kaguya-sama: Love Is War': 1,
#          'Most Beautiful Thing': 1,
#          'Scary Movie 5': 1,
#          'My Mister': 1,
#          'I Want to Get Married': 1,
#          'John Wick': 1,
#          'The Addams Family': 1,
#          'Crazy Delicious': 1,
#          'Making Unorthodox': 1,
#          'The Judge': 1,
#          'Car Masters: Rust to Riches': 1,
#          'Christmas Wonderland': 1,
#          'Moneyball': 1,
#          'Family Feud South Africa': 1,
#          'Dennis the Menace': 1,
#          'Grown Ups 2': 1,
#          'How To Ruin Christmas': 1,
#          'Nihontouitsu Series': 1,
#          'The Town': 1,
#          'Poseidon': 1,
#          'Harry Potter and the Deathly Hallows: Part 1': 1,
#          'Get Even': 1,
#          'The Lord of the Skies': 1,
#          'American Psycho': 1,
#          'Cargo': 1,
#          'Break': 1,
#          'Why Him?': 1,
#          'Nobodys Fool': 1,
#          'Edge of Tomorrow': 1,
#          'Crank': 1,
#          'Sununú: The Revolution of Love': 1,
#          'The Man Standing Next': 1,
#          'Hannibal': 1,
#          'Second Act': 1,
#          '100 Days My Prince': 1,
#          'Mr. Sunshine': 1,
#          'War for the Planet of the Apes': 1,
#          'Love': 1,
#          'Constantine': 1,
#          '47 Meters Down: Uncaged': 1,
#          'Transformers: War for Cybertron': 1,
#          'Hitman: Agent Jun': 1,
#          'The English Game': 1,
#          'Murder on the Orient Express': 1,
#          'Cloudy with a Chance of Meatballs': 1,
#          'Deepwater Horizon': 1,
#          'Nanny McPhee and the Big Bang': 1,
#          'The Good Detective': 1,
#          'Baba Parasi': 1,
#          'Luccas Neto in: Summer Camp 2': 1,
#          'How to Fix a Drug Scandal': 1,
#          'Django Unchained': 1,
#          'Extremely Wicked, Shockingly Evil and Vile': 1,
#          'Holmes and Watson': 1,
#          'Indiana Jones and the Kingdom of the Crystal Skull': 1,
#          'Exodus: Gods and Kings': 1,
#          'Nobody Knows Im Here': 1,
#          'Lara Croft Tomb Raider: The Cradle of Life': 1,
#          'The Legend of Tarzan': 1,
#          'Up in the Air': 1,
#          'The Hunger Games: Mockingjay - Part 1': 1,
#          'The Misfit of Demon King Academy': 1,
#          'Black Mirror: Bandersnatch': 1,
#          'Doctor Stranger': 1,
#          'Darkest Hour': 1,
#          'The Great Wall': 1,
#          'The Unknown Soldier': 1,
#          'Acts of Violence': 1,
#          'Kosti Byoujanni': 1,
#          'BOFURI: I Don’t Want to Get Hurt, so I’ll Max Out My Defense.': 1,
#          'The Founder': 1,
#          'Coming from Insanity': 1,
#          'GIMS: On the Record': 1,
#          'BG: Personal Bodyguard': 1,
#          'Henry Danger': 1,
#          'Sviňa': 1,
#          'Cold Pursuit': 1,
#          'Miami Vice': 1,
#          'Love Island USA': 1,
#          'Rambo: Last Blood': 1,
#          'Fast & Furious Presents: Hobbs & Shaw': 1,
#          'The Grudge': 1,
#          'La Reina del Sur': 1,
#          'Octonauts & the Great Barrier Reef': 1,
#          'Yu Yu Hakusho': 1,
#          'The Late Bloomer': 1,
#          'Shes Out of My League': 1,
#          'Deep Impact': 1,
#          'The Fast and the Furious: Tokyo Drift': 1,
#          'Dark Shadows': 1,
#          'Anitta: Made in Honório': 1,
#          'Before 30': 1,
#          'Helios': 1,
#          'Přes prsty': 1,
#          'Gilmore Girls': 1,
#          'Journey of an African Colony': 1,
#          'Are We There Yet?': 1,
#          'Paul': 1,
#          'Que Leones': 1,
#          'The Teacher': 1,
#          'Chef': 1,
#          'Rumor Has It...': 1,
#          'Kaali Khuhi': 1,
#          'Trial by Media': 1,
#          'Funny Cow': 1,
#          '47 Ronin': 1,
#          'The Panti Sisters': 1,
#          'Can You Keep a Secret?': 1,
#          'White Boy Rick': 1,
#          'My Spy': 1,
#          'Penguins of Madagascar': 1,
#          'The Imitation Game': 1,
#          '21 Bridges': 1,
#          'Silence Is Welcome': 1,
#          'A Thousand Words': 1,
#          'Eyes Wide Shut': 1,
#          'Chappie': 1,
#          'The Twilight Saga: Breaking Dawn - Part 2': 1,
#          'Andhaghaaram': 1,
#          'Cold Case Files': 1,
#          ...})

# %%
type(net_counter)
# Out:
# collections.Counter

# %%
mask = Image.open('./1.png')
mask = np.array(mask)

# %%
wordcloud = WordCloud(scale=3,# 단어별 빈도수로 워드 클라우드 작성 
                font_path='font/NetflixSansMedium.ttf',
                background_color ='black',
                max_font_size=100,
                colormap ='Reds',
                mask= mask2,
                contour_color='#b1060f',
                contour_width=2, 
                repeat=True,
                prefer_horizontal=0.9,
                min_font_size = 20).generate_from_frequencies(net_mask)
image_colors = ImageColorGenerator(mask)
wordcloud = wordcloud.recolor(color_func=image_colors)

plt.figure(figsize = (10, 10), facecolor = None) 
title_font = {
    'fontsize': 30,
    'fontweight': 'bold',
    'color' : 'crimson'
}
plt.title('Netflix', loc='right', pad=20, fontdict=title_font)
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f3d9f0b62990> in <module>
#       4                 max_font_size=100,
#       5                 colormap ='Reds',
# ----> 6                 mask= mask2,
#       7                 contour_color='#b1060f',
#       8                 contour_width=2,
#
# NameError: name 'mask2' is not defined

# %%
mask = Image.open('./3.png')
mask = np.array(mask)
wordcloud = WordCloud(scale=3,# 단어별 빈도수로 워드 클라우드 작성 
                font_path='font/NetflixSansMedium.ttf',
                background_color ='black',
                max_font_size=150,
                colormap ='Reds',
                mask= mask,
                contour_color='#b1060f',
                contour_width=2, 
                repeat=True,
                prefer_horizontal=0.9,
                min_font_size = 10).generate_from_frequencies(net_counter)
image_colors = ImageColorGenerator(mask)
wordcloud = wordcloud.recolor(color_func=image_colors)

plt.figure(figsize = (10, 10), facecolor = None) 
title_font = {
    'fontsize': 30,
    'fontweight': 'bold',
    'color' : 'crimson'
}
plt.title('Netflix', loc='right', pad=20, fontdict=title_font)
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
plt.savefig('Netflix1.png')

# %%
plt.imsave('Netflix.png',wordcloud2)

# %%
plt.savefig("Netflix.png")

# %%
mask = Image.open('./2.png')
mask = np.array(mask2)
wordcloud = WordCloud(scale=3,# 단어별 빈도수로 워드 클라우드 작성 
                font_path='font/NetflixSansMedium.ttf',
                background_color ='black',
                max_font_size=150,
                colormap ='Reds',
                mask= mask,
                contour_color='#b1060f',
                contour_width=2, 
                repeat=True,
                prefer_horizontal=0.9,
                min_font_size = 10).generate_from_frequencies(net_counter)
image_colors = ImageColorGenerator(mask)
wordcloud = wordcloud.recolor(color_func=image_colors)

plt.figure(figsize = (10, 10), facecolor = None) 
title_font = {
    'fontsize': 30,
    'fontweight': 'bold',
    'color' : 'crimson'
}
plt.title('Netflix', loc='right', pad=20, fontdict=title_font)
#plt.imshow(wordcloud)

plt.axis("off") 
plt.tight_layout(pad = 0) 
#plt.show()
plt.savefig("Netflix.pdf", dpi)
