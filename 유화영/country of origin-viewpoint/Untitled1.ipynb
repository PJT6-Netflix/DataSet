# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
from collections import Counter

# %%
df=pd.read_excel('./1. flixpatrol_1.xlsx')

# %%
df.head(1)
# Out:
#    Num              TITLE TYPE        COUNTRY    RELEASE  GENRE  COMPANY  \
# 0    1  The Queens Gambit   TV  United States 2020-10-23  Drama  Netflix
#
#    VALUE
# 0  44867

# %%
df_net = df[['TITLE','VALUE']]

# %%
df_net.head
# Out:
# <bound method NDFrame.head of                      TITLE  VALUE
# 0        The Queens Gambit  44867
# 1                 365 Days  42149
# 2           Emily in Paris  27138
# 3                  Lucifer  25729
# 4     The Umbrella Academy  23480
# ...                    ...    ...
# 3564          Just Friends      1
# 3565   Crank: High Voltage      1
# 3566              Child 44      1
# 3567        Dracula Untold      1
# 3568               Riddick      1
#
# [3569 rows x 2 columns]>

# %%
df_net=df_net.set_index('VALUE')

# %%
df_net
# Out:
#                       TITLE
# VALUE
# 44867     The Queens Gambit
# 42149              365 Days
# 27138        Emily in Paris
# 25729               Lucifer
# 23480  The Umbrella Academy
# ...                     ...
# 1              Just Friends
# 1       Crank: High Voltage
# 1                  Child 44
# 1            Dracula Untold
# 1                   Riddick
#
# [3569 rows x 1 columns]

# %%
type(df_net)
# Out:
# pandas.core.frame.DataFrame

# %%
net_mask = df.B(df_net)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f14b447bcb7c> in <module>
# ----> 1 net_mask = df.B(df_net)
#
# /Users/anaconda3/envs/tsa/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'B'

# %%
net_mask
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-bdb6031d2042> in <module>
# ----> 1 net_mask
#
# NameError: name 'net_mask' is not defined

# %%
net_counter = Counter(df_net.TITLE)

# %%
net_counter
# Out:
# Counter({'The Queens Gambit': 1,
#          '365 Days': 1,
#          'Emily in Paris': 1,
#          'Lucifer': 1,
#          'The Umbrella Academy': 1,
#          'Money Heist': 1,
#          'Dark Desire': 1,
#          'The Crown': 1,
#          'Friends': 1,
#          'Enola Holmes': 1,
#          'Yo soy Betty la fea': 1,
#          'The Christmas Chronicles: Part Two': 1,
#          'Ratched': 1,
#          'Holidate': 1,
#          'Pablo Escobar, The Drug Lord': 1,
#          'Dark': 1,
#          'The Last Dance': 1,
#          'The Old Guard': 1,
#          'Snowpiercer': 1,
#          'The Social Dilemma': 1,
#          '100 Dias Para Enamorarnos': 1,
#          'Project Power': 1,
#          'The Haunting of Bly Manor': 1,
#          'The SpongeBob Movie: Sponge on the Run': 1,
#          'Cursed': 1,
#          'The Kissing Booth 2': 1,
#          'Cobra Kai': 1,
#          'Extraction': 1,
#          'Its Okay to Not Be Okay': 1,
#          'Paw Patrol': 1,
# ...

# %%
type(net_counter)
# Out:
# collections.Counter

# %%
# mask = Image.open('./1.png')
# mask = np.array(mask)

# %%
# wordcloud = WordCloud(scale=3,# 단어별 빈도수로 워드 클라우드 작성 
#                 font_path='font/NetflixSansMedium.ttf',
#                 background_color ='black',
#                 max_font_size=100,
#                 colormap ='Reds',
#                 mask= mask2,
#                 contour_color='#b1060f',
#                 contour_width=2, 
#                 repeat=True,
#                 prefer_horizontal=0.9,
#                 min_font_size = 20).generate_from_frequencies(net_mask)
# image_colors = ImageColorGenerator(mask)
# wordcloud = wordcloud.recolor(color_func=image_colors)

# plt.figure(figsize = (10, 10), facecolor = None) 
# title_font = {
#     'fontsize': 30,
#     'fontweight': 'bold',
#     'color' : 'crimson'
# }
# plt.title('Netflix', loc='right', pad=20, fontdict=title_font)
# plt.imshow(wordcloud) 
# plt.axis("off") 
# plt.tight_layout(pad = 0) 
# plt.show()

# %%
# !cd ..

# %%
# !pwd
# Out:
# /Users/yoohwayoung/PJT-Netflix/Netflix_Analysis/유화영/country of origin-viewpoint

# %%
mask = Image.open('./워드클라우드/3.png')
mask = np.array(mask)
wordcloud = WordCloud(scale=3,# 단어별 빈도수로 워드 클라우드 작성 
                font_path='font/NetflixSansMedium.ttf',
                background_color ='black',
                max_font_size=200,
                colormap ='Reds',
                mask= mask,
                contour_color='#b1060f',
                contour_width=1, 
                #repeat=True,
                prefer_horizontal=0.8,
                min_font_size = 5).generate_from_frequencies(net_counter)
image_colors = ImageColorGenerator(mask)
wordcloud = wordcloud.recolor(color_func=image_colors)
image_colors = ImageColorGenerator(mask)
wordcloud = wordcloud.recolor(color_func=image_colors)

fig = plt.figure(figsize = (10, 10), facecolor = None) 
title_font = {
    'fontsize': 30,
    'fontweight': 'bold',
    'color' : 'crimson'
}
plt.title('Netflix', loc='right', pad=20, fontdict=title_font)
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
plt.savefig('Netflix1.png')

# %%
mask = Image.open('./3.png')
mask = np.array(mask)
wordcloud = WordCloud(scale=3,# 단어별 빈도수로 워드 클라우드 작성 
                font_path='font/NetflixSansMedium.ttf',
                background_color ='black',
                max_font_size=200,
                colormap ='Reds',
                mask= mask,
                contour_color='#b1060f',
                contour_width=1, 
                #repeat=True,
                prefer_horizontal=0.8,
                min_font_size = 5).generate_from_frequencies(net_counter)
image_colors = ImageColorGenerator(mask)
wordcloud = wordcloud.recolor(color_func=image_colors)
# image_colors = ImageColorGenerator(mask)
# wordcloud = wordcloud.recolor(color_func=image_colors)

plt.figure(figsize = (10, 10), facecolor = None) 
title_font = {
    'fontsize': 30,
    'fontweight': 'bold',
    'color' : 'crimson'
}
plt.title('Netflix', loc='right', pad=20, fontdict=title_font)
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
plt.imsave('Netflix.png',wordcloud2)

# %%
plt.savefig("Netflix.png")

# %%
mask = Image.open('./3.png')
mask = np.array(mask)
wordcloud = WordCloud(scale=3,# 단어별 빈도수로 워드 클라우드 작성 
                font_path='font/NetflixSansMedium.ttf',
                background_color ='black',
                max_font_size=200,
                colormap ='Reds',
                mask= mask,
                contour_color='#b1060f',
                contour_width=1, 
                #repeat=True,
                prefer_horizontal=0.8,
                min_font_size = 5).generate_from_frequencies(net_counter)
# image_colors = ImageColorGenerator(mask)
# wordcloud = wordcloud.recolor(color_func=image_colors)


plt.figure(figsize = (10, 10), facecolor = None) 
title_font = {
    'fontsize': 30,
    'fontweight': 'bold',
    'color' : 'crimson'
}
plt.title('Netflix', loc='right', pad=20, fontdict=title_font)
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
